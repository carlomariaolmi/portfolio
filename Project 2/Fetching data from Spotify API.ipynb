# %% [markdown]
# # Retreiving Music features of your favorite playlist using Spotify API
# ______________________
# {info:title=This is my title|icon=false}
# This is _important_ information.
# {info}

# %%
import pandas as pd
from pandas.io.json import json_normalize
import requests
import json
from requests.auth import HTTPBasicAuth

# %%
# %store -r CLIENT_ID
# %store -r CLIENT_SECRET
# %store -r REDIRECT_URI

# %% [markdown]
# ## Requests authentication token
# ______________
# Many methods require user authentication. For these requests you will need to generate an authorization token that indicates that the user has granted permission for your application to perform the given task. You will need to register your app to get the credentials necessary to make authorized calls.
# Spotify supports two authorization flows:
#
# * The Authorization Code flow This method is suitable for long-running applications which the user logs into once. It provides an access token that can be refreshed.
# * The Client Credentials flow The method makes it possible to authenticate your requests to the Spotify Web API and to obtain a higher rate limit than you would
# The method makes it possible to authenticate your requests to the Spotify Web API and to obtain a higher rate limit than you would get without authentication. Note, however that this flow does not include authorization and therefore cannot be used to access or manage a user’s private data.
#
# ![alt text](https://developer.spotify.com/wp-content/uploads/2014/04/Client-Credentials-Flow-Diagram.png)
#
# The request is sent to the /api/token endpoint of the Accounts service:

# %%
def api_request():
    auth = requests.post('https://accounts.spotify.com/api/token',data={'grant_type':'client_credentials'}, auth=HTTPBasicAuth(CLIENT_ID, CLIENT_SECRET))
    if auth.status_code == 200:
        auth_token = auth.json()['access_token']
    else:
        output = 'failed'
    return auth_token 

auth_token = api_request()

# %% [markdown]
# ## Search for an Item
# _______________
# Get Spotify catalog information about artists, albums, tracks or playlists that match a keyword string.
# 1. Endpoints:
#    > GET https://api.spotify.com/v1/search
# 2. Request Parameters:
#    * **q** :  (Required). The search query's keywords (and optional field filters and operators)
#    * **type**  :  (Required). A comma-separated list of item types to search across. Valid types are: album, artist, playlist, and track.
#    * **limit** (Optional). The maximum number of results to return. Default: 20. Minimum: 1. Maximum: 50.

# %%
# Enter the playlist name 
playlist_name = 'Classics 1000'

# %% [markdown]
# There are many different types of requests. The most commonly used one, a GET request, is used to retrieve data.

# %%
req = requests.get(url='https://api.spotify.com/v1/search', params= {'q':playlist_name, 'type':'playlist'}, 
                   headers={"Authorization": "Bearer %s" %auth_token})
resp = req.json() 
playlist_df = json_normalize(resp['playlists']['items'])
#playlist_df.columns
playlist_df = playlist_df[['name', 'id','owner.display_name', 'collaborative', 'tracks.total', 'owner.id']]
playlist_df.columns = [c.replace('.', '_') for c in playlist_df.columns]

# %%
playlist_df
# Out:
#                                                  name                      id  \
# 0                                     Trance Top 1000  5lSgExb6yTKfLusGag7bm7
# 1                       Radio 1: Classics 1000 (2017)  2XDXQi6g4S4f3DWEbqpvMB
# 2                                Classics 1000 (2017)  0jGnqUcgDY4zOmmxYJLlqn
# 3   Christmas Carols & Hymns | Classic Xmas Playlists  7tRCqwkjjEiatrAl2668wL
# 4                    VRT Radio 1 Classics 1000 (2016)  0jUlgQ4AoxTEdEvjgv94Mp
# 5                                  Chill Out Top 1000  68BiK8KG3otORDaYB3ZaO9
# 6                           Radio 1 classics top 1000  6qoTGHkayNwJIt5MgKs3RD
# 7   Trance Top 1000 (The Best Trance Classics Ever...  5GM8RIdreNE9HGYdxxWLgo
# 8                               I'd Walk a 1000 Miles  1VxPnfj1gCfsJyll3t7AlY
# 9   Top 1000 Classic Rock Songs Rock'n Roll America's  0WLRtXD58hjBvAHeUdkBf7
# 10  Rock | Blues | Guitar | Soul | Indie | Jazz | ...  7tkrMfB4g5eexb0pZ139EL
# 11  Wilson Pickett - Official Playlist - Land Of 1...  5TDA0nF6vb2zx1wUibHvwC
# 12                                       Classic 1000  59uzQd8qJaohGgp78oXwPF
# 13  Trance Top 1000 - The Best Trance Classics Eve...  6Cldx5q1ATMFgWZjVTCjBX
# 14            Top 1000 Classic Rock Songs of all time  5tIwrixCdPzNYi6cXSoAy7
# 15                     Top 1000 Classic chinese songs  4R3NZRAkwuTS11LT1CvqzI
# 16                           POP (Forgotten Classics)  2K1niI854mvtRyAcutyWQD
# 17                     Top 1000+ Disco Dance Classics  7fmWp32vrXreC4iBzMfRu3
# 18                                   1000 Of The Best  1CYoYVJQx6igJV2v7Ju7H2
# 19  Trance Energy Top 1000 - Tomorrowland 2017 (Th...  0qVhEGXLMPINpKH6TWeH4o
#
#              owner_display_name collaborative  tracks_total  \
# 0                 Armada Music          False          1000
# 1               Kristof De Beuf         False           986
# 2                           NaN         False           978
# 3   Christmas Songs & Playlists         False            35
# 4                           NaN         False           962
# 5                 Armada Music          False          1000
# 6                   David Apers         False           961
# 7                           NaN         False          1000
# 8       Benjamin Edward Ramirez         False            20
# 9                Fernando Brito         False           566
# 10                Cihan Scherer         False          1542
# 11               Wilson Pickett         False            16
# 12                          NaN         False           978
# 13                          NaN         False           996
# 14                          NaN         False          1007
# 15                Robert Barker         False          1000
# 16                          NaN         False          1326
# 17                          NaN         False          1416
# 18                  David Grant         False           881
# 19                          NaN         False          1000
#
#                      owner_id
# 0         armadamusicofficial
# 1                casablanca81
# 2                    radio1be
# 3             christmas.songs
# 4                    radio1be
# 5         armadamusicofficial
# 6                   117798317
# 7                   gallihani
# 8                   124562560
# 9                  1154055994
# 10                11123441710
# 11           wilsonpickettvip
# 12           dieterdevlamynck
# 13                 1134732240
# 14                    1rene78
# 15  22uoc7jsej7azab2krenxs3ai
# 16                  vengy2005
# 17               robvanmullem
# 18                 1259160290
# 19                recallicall

# %%
# enter index playlist
n = 1
name = playlist_df['name'][n]
total = playlist_df['tracks_total'][n]
print 'Playlist name: %s' % name
print 'Total numeber of tracks: %d' % total
# Out:
# Playlist name: Radio 1: Classics 1000 (2017)
# Total numeber of tracks: 986

# %% [markdown]
# ## Enjoy the playlist! 😊🎧
# <iframe src="https://open.spotify.com/embed/user/casablanca81/playlist/2XDXQi6g4S4f3DWEbqpvMB" width="340" height="380" frameborder="0" allowtransparency="False">

# %% [markdown]
# ## Get a Playlist’s Tracks
# ______________
# Get full details of the tracks of a playlist owned by a Spotify user.
# 1. Endpoints:
#    > GET https://api.spotify.com/v1/users/{user_id}/playlists/{playlist_id}/tracks
# 2. Path Parameters:
#    * **user_id** :  The user's Spotify user ID.
#    * **playlist_id**  :  The Spotify ID for the playlist.
# 3. Query Parameters:
#    * **limit** : Optional. The maximum number of tracks to return. Default: 100. Minimum: 1. Maximum: 100.
#    * **offset**  :  Optional. The index of the first track to return. Default: 0 (the first object).
# ### Pagination
# Some endpoints support a way of paging the dataset, taking an offset and limit as query parameters:
#
# **curl "https://api.spotify.com/v1/artists/1vCWHaC5f2uS3yhpwWbIA6/albums?album_type=SINGLE&offset=20&limit=10"**
#
# Note that offset numbering is zero-based and that omitting the offset parameter will return the first X elements. Check the documentation for the specific endpoint to see the default limit value. Requests that return an array of items are automatically paginated if the number of items vary (for example, tracks in a playlist). In this case, the results are returned within a paging object.

# %%
## we need to support pagination
def get_playlist_tracks():
    #columns=['track.id','track.artists', 'track.name' ]
    playlist_tracks=pd.DataFrame()
    limit=50 #set the number of albums to retrieve from API, 50 is the max
    offset=0 #The index of the first album to return. Default: 0 (i.e., the first album)
    total=limit
    while total> offset:
        req = requests.get(url='http://api.spotify.com/v1/users/{user_id}/playlists/{id}/tracks'.format(user_id=playlist_df['owner_id'][n], id=playlist_df['id'][n]),
                 params= {'limit':limit, 'offset':offset}, headers={"Authorization": "Bearer %s" %auth_token})
        resp_albums = req.json()
        playlist_tracks = playlist_tracks.append(json_normalize(resp_albums['items']), ignore_index=True)
        ##read the total from response and update offset
        total = playlist_df['tracks_total'][n]  #resp_albums['total']
        offset = offset + limit 
        print ('TOTAL: %d, OFFSET: %d' % (total, offset))
    return playlist_tracks

# %%
tracks_df = get_playlist_tracks()
#df.columns
# Out:
# TOTAL: 986, OFFSET: 50
# TOTAL: 986, OFFSET: 100
# TOTAL: 986, OFFSET: 150
# TOTAL: 986, OFFSET: 200
# TOTAL: 986, OFFSET: 250
# TOTAL: 986, OFFSET: 300
# TOTAL: 986, OFFSET: 350
# TOTAL: 986, OFFSET: 400
# TOTAL: 986, OFFSET: 450
# TOTAL: 986, OFFSET: 500
# TOTAL: 986, OFFSET: 550
# TOTAL: 986, OFFSET: 600
# TOTAL: 986, OFFSET: 650
# TOTAL: 986, OFFSET: 700
# TOTAL: 986, OFFSET: 750
# TOTAL: 986, OFFSET: 800
# TOTAL: 986, OFFSET: 850
# TOTAL: 986, OFFSET: 900
# TOTAL: 986, OFFSET: 950
# TOTAL: 986, OFFSET: 1000

# %%
tracks_df.columns = [c.replace('.', '_') for c in tracks_df.columns]
tracks_df.head()
# Out:
#                added_at              added_by_external_urls_spotify  \
# 0  2017-04-15T15:50:23Z  https://open.spotify.com/user/casablanca81
# 1  2017-04-15T15:41:47Z  https://open.spotify.com/user/casablanca81
# 2  2017-04-15T15:35:19Z  https://open.spotify.com/user/casablanca81
# 3  2017-04-15T15:24:26Z  https://open.spotify.com/user/casablanca81
# 4  2017-04-15T15:19:18Z  https://open.spotify.com/user/casablanca81
#
#                                    added_by_href   added_by_id added_by_type  \
# 0  https://api.spotify.com/v1/users/casablanca81  casablanca81          user
# 1  https://api.spotify.com/v1/users/casablanca81  casablanca81          user
# 2  https://api.spotify.com/v1/users/casablanca81  casablanca81          user
# 3  https://api.spotify.com/v1/users/casablanca81  casablanca81          user
# 4  https://api.spotify.com/v1/users/casablanca81  casablanca81          user
#
#                 added_by_uri is_local track_album_album_type  \
# 0  spotify:user:casablanca81    False                  album
# 1  spotify:user:casablanca81    False                  album
# 2  spotify:user:casablanca81    False                  album
# 3  spotify:user:casablanca81    False            compilation
# 4  spotify:user:casablanca81    False                  album
#
#                                  track_album_artists  \
# 0  [{u'name': u'Led Zeppelin', u'external_urls': ...
# 1  [{u'name': u'David Bowie', u'external_urls': {...
# 2  [{u'name': u'Queen', u'external_urls': {u'spot...
# 3  [{u'name': u'Deep Purple', u'external_urls': {...
# 4  [{u'name': u'Pink Floyd', u'external_urls': {u...
#
#                        track_album_available_markets  \
# 0                                                 []
# 1  [AD, AR, AT, AU, BE, BG, BO, BR, CA, CH, CL, C...
# 2  [AD, AR, AT, AU, BE, BG, BO, BR, CH, CL, CO, C...
# 3  [AD, AR, AT, AU, BE, BG, BO, BR, CH, CL, CO, C...
# 4  [AD, AT, BE, BG, CH, CY, CZ, DE, DK, EE, ES, F...
#
#                    ...                  track_external_ids_isrc  \
# 0                  ...                             USAT29900620
# 1                  ...                             USJT19900130
# 2                  ...                             GBUM71029604
# 3                  ...                             GBDXG0600057
# 4                  ...                             GBN9Y1100088
#
#                          track_external_urls_spotify  \
# 0  https://open.spotify.com/track/51pQ7vY7WXzxskw...
# 1  https://open.spotify.com/track/5j6ZZwA9BnxZi5B...
# 2  https://open.spotify.com/track/1AhDOtG9vPSOmsW...
# 3  https://open.spotify.com/track/21cp8L9Pei4Agys...
# 4  https://open.spotify.com/track/5MVrZa7cDtnAoMv...
#
#                                           track_href                track_id  \
# 0  https://api.spotify.com/v1/tracks/51pQ7vY7WXzx...  51pQ7vY7WXzxskwloaeqyj
# 1  https://api.spotify.com/v1/tracks/5j6ZZwA9BnxZ...  5j6ZZwA9BnxZi5Bk0Ng4jB
# 2  https://api.spotify.com/v1/tracks/1AhDOtG9vPSO...  1AhDOtG9vPSOmsWgNW0BEY
# 3  https://api.spotify.com/v1/tracks/21cp8L9Pei4A...  21cp8L9Pei4AgysZVihjSv
# 4  https://api.spotify.com/v1/tracks/5MVrZa7cDtnA...  5MVrZa7cDtnAoMvCgRAMqb
#
#                                      track_name track_popularity  \
# 0                            Stairway To Heaven               30
# 1              Heroes - 1999 Remastered Version               73
# 2           Bohemian Rhapsody - Remastered 2011               79
# 3                                 Child In Time               58
# 4  Wish You Were Here - 2011 Remastered Version               70
#
#                                    track_preview_url track_track_number  \
# 0                                               None                  4
# 1  https://p.scdn.co/mp3-preview/a4b800deff2a82c4...                  3
# 2                                               None                 11
# 3  https://p.scdn.co/mp3-preview/3198981a063c06f9...                  5
# 4  https://p.scdn.co/mp3-preview/7ce0d4e5f0ffcf8f...                  4
#
#   track_type                             track_uri
# 0      track  spotify:track:51pQ7vY7WXzxskwloaeqyj
# 1      track  spotify:track:5j6ZZwA9BnxZi5Bk0Ng4jB
# 2      track  spotify:track:1AhDOtG9vPSOmsWgNW0BEY
# 3      track  spotify:track:21cp8L9Pei4AgysZVihjSv
# 4      track  spotify:track:5MVrZa7cDtnAoMvCgRAMqb
#
# [5 rows x 32 columns]

# %%
tracks_df["artist_name"]=tracks_df.track_artists.apply(lambda x: x[0]["name"])
tracks_df=tracks_df.drop(["track_artists"], axis=1)

# %%
tracks_df = tracks_df[['track_name','artist_name', 'track_id', 'track_popularity', 'track_duration_ms']]
tracks_df.head()
# Out:
#                                      track_name   artist_name  \
# 0                            Stairway To Heaven  Led Zeppelin
# 1              Heroes - 1999 Remastered Version   David Bowie
# 2           Bohemian Rhapsody - Remastered 2011         Queen
# 3                                 Child In Time   Deep Purple
# 4  Wish You Were Here - 2011 Remastered Version    Pink Floyd
#
#                  track_id  track_popularity  track_duration_ms
# 0  51pQ7vY7WXzxskwloaeqyj                30             478173
# 1  5j6ZZwA9BnxZi5Bk0Ng4jB                73             370373
# 2  1AhDOtG9vPSOmsWgNW0BEY                79             354320
# 3  21cp8L9Pei4AgysZVihjSv                58             619266
# 4  5MVrZa7cDtnAoMvCgRAMqb                70             334743

# %%
tracks_df=tracks_df.drop_duplicates(['track_id'])
tracks_df['id'] = tracks_df['track_id']
tracks_df = tracks_df

# %% [markdown]
# ## Get Audio Features for a Track
# ______________________
# Get full details of the tracks of a playlist owned by a Spotify user.
# 1. Endpoints:
#    > GET https://api.spotify.com/v1/audio-features/{id}
# 2. Path Parameters:
#    * **id** :  	Required. The Spotify ID for the track.
# 3. Audio Features Object:
#    * **acousticness** (float): A confidence measure from 0.0 to 1.0 of whether the track is acoustic. 1.0 represents high confidence the track is acoustic.
#    * **danceability** (float): Danceability describes how suitable a track is for dancing based on a combination of musical elements including tempo, rhythm stability, beat strength, and overall regularity. A value of 0.0 is least danceable and 1.0 is most danceable.
#    * **duration_ms** (int): The duration of the track in milliseconds.
#    * **energy** (float): Energy is a measure from 0.0 to 1.0 and represents a perceptual measure of intensity and activity. Typically, energetic tracks feel fast, loud, and noisy. For example, death metal has high energy, while a Bach prelude scores low on the scale. Perceptual features contributing to this attribute include dynamic range, perceived loudness, timbre, onset rate, and general entropy.
#    * **instrumentalness** (float): Predicts whether a track contains no vocals. "Ooh" and "aah" sounds are treated as instrumental in this context. Rap or spoken word tracks are clearly "vocal". The closer the instrumentalness value is to 1.0, the greater likelihood the track contains no vocal content. Values above 0.5 are intended to represent instrumental tracks, but confidence is higher as the value approaches 1.0.
#    * **key** (int): The key the track is in. Integers map to pitches using standard Pitch Class notation. E.g. 0 = C, 1 = C♯/D♭, 2 = D, and so on.
#    * **liveness** (float): Detects the presence of an audience in the recording. Higher liveness values represent an increased probability that the track was performed live. A value above 0.8 provides strong likelihood that the track is live.
#    * **loudness** (float): The overall loudness of a track in decibels (dB). Loudness values are averaged across the entire track and are useful for comparing relative loudness of tracks. Loudness is the quality of a sound that is the primary psychological correlate of physical strength (amplitude). Values typical range between -60 and 0 db.
#    * **speechiness** (float): Speechiness detects the presence of spoken words in a track. The more exclusively speech-like the recording (e.g. talk show, audio book, poetry), the closer to 1.0 the attribute value. Values above 0.66 describe tracks that are probably made entirely of spoken words. Values between 0.33 and 0.66 describe tracks that may contain both music and speech, either in sections or layered, including such cases as rap music. Values below 0.33 most likely represent music and other non-speech-like tracks.
#    * **tempo** (float): The overall estimated tempo of a track in beats per minute (BPM). In musical terminology, tempo is the speed or pace of a given piece and derives directly from the average beat duration.
#    * **valence** (float): A measure from 0.0 to 1.0 describing the musical positiveness conveyed by a track. Tracks with high valence sound more positive (e.g. happy, cheerful, euphoric), while tracks with low valence sound more negative (e.g. sad, depressed, angry).

# %%
def get_audio_features():
    auth_token = api_request()    
    ##using access token you can now autorize and get audio features for a track 
    track_audio_features= list(map(lambda x: requests.get('https://api.spotify.com/v1/audio-features/{track_id}'.format(track_id=x), 
                                                          headers={"Authorization": "Bearer %s" %auth_token}).json(), tracks_df.track_id))

    return json_normalize(track_audio_features)

# %%
features_df = get_audio_features()
features_df.head()
# Out:
#    acousticness                                       analysis_url  \
# 0      0.575000  https://api.spotify.com/v1/audio-analysis/51pQ...
# 1      0.000265  https://api.spotify.com/v1/audio-analysis/5j6Z...
# 2      0.271000  https://api.spotify.com/v1/audio-analysis/1AhD...
# 3      0.313000  https://api.spotify.com/v1/audio-analysis/21cp...
# 4      0.735000  https://api.spotify.com/v1/audio-analysis/5MVr...
#
#    danceability  duration_ms  energy                      id  \
# 0         0.346       478173   0.335  51pQ7vY7WXzxskwloaeqyj
# 1         0.478       370373   0.774  5j6ZZwA9BnxZi5Bk0Ng4jB
# 2         0.414       354320   0.404  1AhDOtG9vPSOmsWgNW0BEY
# 3         0.331       619267   0.340  21cp8L9Pei4AgysZVihjSv
# 4         0.481       334744   0.262  5MVrZa7cDtnAoMvCgRAMqb
#
#    instrumentalness  key  liveness  loudness  mode  speechiness    tempo  \
# 0           0.00674    7     0.185   -12.453     1       0.0339   84.204
# 1           0.58500    7     0.191    -6.977     1       0.0292  112.577
# 2           0.00000    0     0.300    -9.928     0       0.0499   71.105
# 3           0.60700    9     0.234   -14.784     0       0.0369  126.672
# 4           0.01140    7     0.832   -15.730     1       0.0414  122.883
#
#    time_signature                                         track_href  \
# 0               4  https://api.spotify.com/v1/tracks/51pQ7vY7WXzx...
# 1               4  https://api.spotify.com/v1/tracks/5j6ZZwA9BnxZ...
# 2               4  https://api.spotify.com/v1/tracks/1AhDOtG9vPSO...
# 3               4  https://api.spotify.com/v1/tracks/21cp8L9Pei4A...
# 4               4  https://api.spotify.com/v1/tracks/5MVrZa7cDtnA...
#
#              type                                   uri  valence
# 0  audio_features  spotify:track:51pQ7vY7WXzxskwloaeqyj    0.213
# 1  audio_features  spotify:track:5j6ZZwA9BnxZi5Bk0Ng4jB    0.429
# 2  audio_features  spotify:track:1AhDOtG9vPSOmsWgNW0BEY    0.224
# 3  audio_features  spotify:track:21cp8L9Pei4AgysZVihjSv    0.365
# 4  audio_features  spotify:track:5MVrZa7cDtnAoMvCgRAMqb    0.375

# %%
features_df['track_id'] = features_df['id']
features_df.tail()
# Out:
#      acousticness                                       analysis_url  \
# 981      0.634000  https://api.spotify.com/v1/audio-analysis/0IqK...
# 982      0.000085  https://api.spotify.com/v1/audio-analysis/1yea...
# 983      0.197000  https://api.spotify.com/v1/audio-analysis/7KeW...
# 984      0.678000  https://api.spotify.com/v1/audio-analysis/6lEe...
# 985      0.759000  https://api.spotify.com/v1/audio-analysis/4GHF...
#
#      danceability  duration_ms  energy                      id  \
# 981         0.566       241688   0.664  0IqKeD8ZSP72KbGYyzEcAs
# 982         0.509       236533   0.769  1yea9mxOFUgcXOt5cgiBT6
# 983         0.515       244027   0.599  7KeWURzF9Q6aIEaBRSyA0N
# 984         0.423       299507   0.430  6lEexSNsP2UZq9x1EETWL4
# 985         0.533       159427   0.871  4GHF75LwRT2Hsv9z3ZXpM8
#
#      instrumentalness  key  liveness  loudness  mode  speechiness    tempo  \
# 981          0.000000    4     0.116    -5.303     0       0.0464  128.945
# 982          0.003630   11     0.130    -7.527     1       0.0315  121.439
# 983          0.001530    0     0.115    -9.268     1       0.0372   78.626
# 984          0.003370    9     0.247   -12.016     0       0.0397  124.470
# 985          0.000186   10     0.337    -6.085     1       0.0656  167.841
#
#      time_signature                                         track_href  \
# 981               4  https://api.spotify.com/v1/tracks/0IqKeD8ZSP72...
# 982               4  https://api.spotify.com/v1/tracks/1yea9mxOFUgc...
# 983               4  https://api.spotify.com/v1/tracks/7KeWURzF9Q6a...
# 984               4  https://api.spotify.com/v1/tracks/6lEexSNsP2UZ...
# 985               4  https://api.spotify.com/v1/tracks/4GHF75LwRT2H...
#
#                type                                   uri  valence  \
# 981  audio_features  spotify:track:0IqKeD8ZSP72KbGYyzEcAs   0.4370
# 982  audio_features  spotify:track:1yea9mxOFUgcXOt5cgiBT6   0.4640
# 983  audio_features  spotify:track:7KeWURzF9Q6aIEaBRSyA0N   0.5930
# 984  audio_features  spotify:track:6lEexSNsP2UZq9x1EETWL4   0.0416
# 985  audio_features  spotify:track:4GHF75LwRT2Hsv9z3ZXpM8   0.9700
#
#                    track_id
# 981  0IqKeD8ZSP72KbGYyzEcAs
# 982  1yea9mxOFUgcXOt5cgiBT6
# 983  7KeWURzF9Q6aIEaBRSyA0N
# 984  6lEexSNsP2UZq9x1EETWL4
# 985  4GHF75LwRT2Hsv9z3ZXpM8

# %%
result = pd.merge(features_df, tracks_df, how='left', on=['track_id', 'track_id'])
result.head()
# Out:
#    acousticness                                       analysis_url  \
# 0      0.575000  https://api.spotify.com/v1/audio-analysis/51pQ...
# 1      0.000265  https://api.spotify.com/v1/audio-analysis/5j6Z...
# 2      0.271000  https://api.spotify.com/v1/audio-analysis/1AhD...
# 3      0.313000  https://api.spotify.com/v1/audio-analysis/21cp...
# 4      0.735000  https://api.spotify.com/v1/audio-analysis/5MVr...
#
#    danceability  duration_ms  energy                    id_x  \
# 0         0.346       478173   0.335  51pQ7vY7WXzxskwloaeqyj
# 1         0.478       370373   0.774  5j6ZZwA9BnxZi5Bk0Ng4jB
# 2         0.414       354320   0.404  1AhDOtG9vPSOmsWgNW0BEY
# 3         0.331       619267   0.340  21cp8L9Pei4AgysZVihjSv
# 4         0.481       334744   0.262  5MVrZa7cDtnAoMvCgRAMqb
#
#    instrumentalness  key  liveness  loudness           ...            \
# 0           0.00674    7     0.185   -12.453           ...
# 1           0.58500    7     0.191    -6.977           ...
# 2           0.00000    0     0.300    -9.928           ...
# 3           0.60700    9     0.234   -14.784           ...
# 4           0.01140    7     0.832   -15.730           ...
#
#                                           track_href            type  \
# 0  https://api.spotify.com/v1/tracks/51pQ7vY7WXzx...  audio_features
# 1  https://api.spotify.com/v1/tracks/5j6ZZwA9BnxZ...  audio_features
# 2  https://api.spotify.com/v1/tracks/1AhDOtG9vPSO...  audio_features
# 3  https://api.spotify.com/v1/tracks/21cp8L9Pei4A...  audio_features
# 4  https://api.spotify.com/v1/tracks/5MVrZa7cDtnA...  audio_features
#
#                                     uri  valence                track_id  \
# 0  spotify:track:51pQ7vY7WXzxskwloaeqyj    0.213  51pQ7vY7WXzxskwloaeqyj
# 1  spotify:track:5j6ZZwA9BnxZi5Bk0Ng4jB    0.429  5j6ZZwA9BnxZi5Bk0Ng4jB
# 2  spotify:track:1AhDOtG9vPSOmsWgNW0BEY    0.224  1AhDOtG9vPSOmsWgNW0BEY
# 3  spotify:track:21cp8L9Pei4AgysZVihjSv    0.365  21cp8L9Pei4AgysZVihjSv
# 4  spotify:track:5MVrZa7cDtnAoMvCgRAMqb    0.375  5MVrZa7cDtnAoMvCgRAMqb
#
#                                      track_name   artist_name  \
# 0                            Stairway To Heaven  Led Zeppelin
# 1              Heroes - 1999 Remastered Version   David Bowie
# 2           Bohemian Rhapsody - Remastered 2011         Queen
# 3                                 Child In Time   Deep Purple
# 4  Wish You Were Here - 2011 Remastered Version    Pink Floyd
#
#    track_popularity track_duration_ms                    id_y
# 0                30            478173  51pQ7vY7WXzxskwloaeqyj
# 1                73            370373  5j6ZZwA9BnxZi5Bk0Ng4jB
# 2                79            354320  1AhDOtG9vPSOmsWgNW0BEY
# 3                58            619266  21cp8L9Pei4AgysZVihjSv
# 4                70            334743  5MVrZa7cDtnAoMvCgRAMqb
#
# [5 rows x 24 columns]

# %%
results = pd.DataFrame(result)
results.columns
# Out:
# Index([     u'acousticness',      u'analysis_url',      u'danceability',
#              u'duration_ms',            u'energy',              u'id_x',
#         u'instrumentalness',               u'key',          u'liveness',
#                 u'loudness',              u'mode',       u'speechiness',
#                    u'tempo',    u'time_signature',        u'track_href',
#                     u'type',               u'uri',           u'valence',
#                 u'track_id',        u'track_name',       u'artist_name',
#         u'track_popularity', u'track_duration_ms',              u'id_y'],
#       dtype='object')

# %%
df = results[['acousticness', 'instrumentalness', 'loudness', 'tempo','danceability', 'liveness' ,'valence', 'energy', 'speechiness']]
df.describe()
# Out:
#        acousticness  instrumentalness    loudness       tempo  danceability  \
# count    986.000000        986.000000  986.000000  986.000000    986.000000
# mean       0.345102          0.069764  -10.316688  120.140137      0.543658
# std        0.305380          0.184653    3.712828   27.067488      0.150426
# min        0.000008          0.000000  -27.344000   37.114000      0.107000
# 25%        0.060225          0.000004  -12.591500  103.232250      0.438250
# 50%        0.249500          0.000333   -9.936000  119.640000      0.542000
# 75%        0.604750          0.014775   -7.659750  133.758500      0.648000
# max        0.984000          0.993000   -1.506000  217.578000      0.965000
#
#          liveness     valence      energy  speechiness
# count  986.000000  986.000000  986.000000   986.000000
# mean     0.179038    0.538064    0.546339     0.047253
# std      0.156693    0.248418    0.227210     0.045532
# min      0.023700    0.038100    0.006810     0.022800
# 25%      0.090500    0.344000    0.369250     0.030800
# 50%      0.121000    0.532000    0.546000     0.035900
# 75%      0.204000    0.744500    0.727000     0.046375
# max      0.965000    0.975000    0.989000     0.896000

# %%
df.to_csv('playlist_data.csv', encoding='utf-8', index=False)

# %%
df = pd.read_csv('playlist_data.csv')
df
# Out:
#      acousticness  instrumentalness  loudness    tempo  danceability  \
# 0        0.575000          0.006740   -12.453   84.204         0.346
# 1        0.000265          0.585000    -6.977  112.577         0.478
# 2        0.271000          0.000000    -9.928   71.105         0.414
# 3        0.313000          0.607000   -14.784  126.672         0.331
# 4        0.735000          0.011400   -15.730  122.883         0.481
# 5        0.179000          0.000028   -11.248  117.498         0.587
# 6        0.323000          0.000000    -6.457   77.150         0.360
# 7        0.771000          0.697000   -11.938  137.941         0.266
# 8        0.035300          0.002280   -10.422  113.066         0.367
# 9        0.729000          0.000000    -6.836   95.261         0.483
# 10       0.077100          0.024800    -9.992  148.192         0.731
# 11       0.005010          0.000021    -4.199  146.347         0.270
# 12       0.907000          0.183000   -12.358   75.752         0.547
# 13       0.975000          0.159000   -19.314  120.889         0.269
# 14       0.021900          0.001060   -12.062  135.680         0.597
# 15       0.005740          0.000494    -9.484  147.125         0.579
# 16       0.150000          0.308000   -12.595  127.167         0.472
# 17       0.022600          0.000754    -5.764  113.871         0.426
# 18       0.365000          0.652000   -11.285  163.107         0.579
# 19       0.041100          0.000123   -16.929  113.571         0.697
# 20       0.290000          0.000106   -14.162  163.219         0.364
# 21       0.726000          0.006680   -14.477  139.077         0.254
# 22       0.000032          0.000110    -4.509  116.746         0.512
# 23       0.737000          0.006160   -10.561   98.009         0.430
# 24       0.000185          0.309000   -11.882  110.181         0.538
# 25       0.253000          0.000000    -7.525  117.072         0.521
# 26       0.666000          0.000906    -7.717   90.320         0.536
# 27       0.531000          0.801000   -13.904   79.273         0.413
# 28       0.007520          0.000461    -6.069   75.009         0.284
# 29       0.853000          0.000370   -11.076   83.144         0.542
# ..            ...               ...       ...      ...           ...
# 956      0.173000          0.000288    -7.599  125.664         0.612
# 957      0.036500          0.000007    -8.214  103.940         0.811
# 958      0.147000          0.000000   -13.875   98.530         0.749
# 959      0.000024          0.000016    -3.372   86.446         0.107
# 960      0.131000          0.200000    -7.587  106.027         0.545
# 961      0.495000          0.000001   -13.741   99.710         0.611
# 962      0.044200          0.000001   -12.529   87.724         0.368
# 963      0.119000          0.508000    -4.976  127.001         0.632
# 964      0.197000          0.784000    -8.432  126.283         0.627
# 965      0.676000          0.536000   -10.617  123.964         0.518
# 966      0.865000          0.000016   -10.873  140.587         0.365
# 967      0.002940          0.012900   -11.108  103.249         0.776
# 968      0.640000          0.000000   -13.683   78.927         0.521
# 969      0.913000          0.000077   -15.326  136.168         0.346
# 970      0.122000          0.000026   -10.077  129.712         0.658
# 971      0.042700          0.002630    -8.898  123.475         0.817
# 972      0.475000          0.001530   -14.032  122.262         0.599
# 973      0.434000          0.000001    -7.717  130.109         0.700
# 974      0.717000          0.000000    -6.874  143.603         0.464
# 975      0.910000          0.000003   -23.032   78.856         0.505
# 976      0.040700          0.003540   -12.998  124.897         0.643
# 977      0.001250          0.001110    -8.369  141.175         0.368
# 978      0.127000          0.000012    -3.682  104.458         0.432
# 979      0.177000          0.000569   -16.170   76.785         0.326
# 980      0.215000          0.128000    -9.817  130.029         0.529
# 981      0.634000          0.000000    -5.303  128.945         0.566
# 982      0.000085          0.003630    -7.527  121.439         0.509
# 983      0.197000          0.001530    -9.268   78.626         0.515
# 984      0.678000          0.003370   -12.016  124.470         0.423
# 985      0.759000          0.000186    -6.085  167.841         0.533
#
#      liveness  valence  energy  speechiness
# 0      0.1850   0.2130  0.3350       0.0339
# 1      0.1910   0.4290  0.7740       0.0292
# 2      0.3000   0.2240  0.4040       0.0499
# 3      0.2340   0.3650  0.3400       0.0369
# 4      0.8320   0.3750  0.2620       0.0414
# 5      0.3050   0.5900  0.5360       0.0304
# 6      0.3400   0.2000  0.6840       0.0308
# 7      0.1070   0.0397  0.2940       0.0291
# 8      0.6890   0.1890  0.4520       0.0307
# 9      0.1890   0.5620  0.7210       0.0320
# 10     0.3340   0.9330  0.7970       0.0309
# 11     0.1160   0.6060  0.9440       0.0975
# 12     0.0935   0.1690  0.2570       0.0252
# 13     0.1380   0.2320  0.1510       0.0364
# 14     0.1020   0.8230  0.8120       0.0315
# 15     0.0575   0.6090  0.5080       0.0270
# 16     0.0837   0.1710  0.3660       0.0286
# 17     0.2950   0.5750  0.8220       0.0373
# 18     0.0955   0.4350  0.6220       0.0563
# 19     0.1030   0.2330  0.2980       0.0319
# 20     0.9220   0.1750  0.4570       0.0675
# 21     0.1230   0.2750  0.2210       0.0360
# 22     0.1020   0.6920  0.9050       0.0573
# 23     0.0924   0.3670  0.2400       0.0526
# 24     0.1390   0.1160  0.4320       0.0295
# 25     0.0579   0.4830  0.4870       0.0299
# 26     0.0841   0.1460  0.4000       0.0263
# 27     0.1830   0.1440  0.2960       0.0277
# 28     0.4020   0.5950  0.8750       0.0422
# 29     0.0826   0.4350  0.2970       0.0319
# ..        ...      ...     ...          ...
# 956    0.7560   0.4510  0.7030       0.0341
# 957    0.0799   0.6250  0.4100       0.0392
# 958    0.1750   0.8660  0.4750       0.0737
# 959    0.3600   0.1890  0.8340       0.0450
# 960    0.0921   0.1150  0.8590       0.0682
# 961    0.0650   0.7540  0.3960       0.1780
# 962    0.1120   0.4020  0.5620       0.0305
# 963    0.1140   0.3630  0.9200       0.0531
# 964    0.4040   0.8670  0.8020       0.0348
# 965    0.1240   0.6940  0.4060       0.0405
# 966    0.1290   0.3050  0.2150       0.0301
# 967    0.0598   0.5700  0.8710       0.0519
# 968    0.2450   0.4090  0.2330       0.0254
# 969    0.0934   0.1160  0.1390       0.0321
# 970    0.1830   0.2060  0.3860       0.0473
# 971    0.3580   0.6920  0.7160       0.1440
# 972    0.2350   0.6070  0.5330       0.0472
# 973    0.0963   0.6410  0.7260       0.0329
# 974    0.1510   0.4760  0.4600       0.0393
# 975    0.0675   0.3090  0.0477       0.0278
# 976    0.0237   0.8740  0.5150       0.0391
# 977    0.3010   0.5320  0.9280       0.0593
# 978    0.1410   0.6250  0.8950       0.0504
# 979    0.0828   0.3440  0.3130       0.0348
# 980    0.3660   0.7690  0.6420       0.0371
# 981    0.1160   0.4370  0.6640       0.0464
# 982    0.1300   0.4640  0.7690       0.0315
# 983    0.1150   0.5930  0.5990       0.0372
# 984    0.2470   0.0416  0.4300       0.0397
# 985    0.3370   0.9700  0.8710       0.0656
#
# [986 rows x 9 columns]
